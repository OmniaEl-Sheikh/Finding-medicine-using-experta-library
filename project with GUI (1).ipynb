# %%
from tkinter import *
from experta import *
class find_medicine(KnowledgeEngine):
	@DefFacts()
	def _initial_action(self):
		gui_form1 = Tk()
        
		gui_form1.title("Medical system")
		gui_form1.config(background='wheat')
		fr1 = Frame(width='900', height='500', background='wheat')
		fr1.place(x=10, y=10)
		gui_form1.geometry("900x700")
		lb0 = Label(gui_form1, justify='center', font=5,text="Hi! I will help you find the right medication for you.\nFor that you'll have to answer a few questions about your conditions\nDo you feel any of the following symptoms:",bg="#123456", fg="#fff",width="800")
		lb0.pack()
###############################################################################
		lb1 = Label(gui_form1,text="headache:",bg='white', font=5)
		en1 = Entry(gui_form1, justify='center', font=5)
		lb1.place(x=160,y=100)
		en1.place(x=450,y=100)
###############################################################################
		lb2 = Label(gui_form1,text="runny nose:",bg='white', font=5)
		en2 = Entry(gui_form1, justify='center', font=5)
		lb2.place(x=160,y=140)
		en2.place(x=450,y=140)
###############################################################################
		lb3 = Label(gui_form1,text="The limbs shiver:",bg='white', font=5)
		en3 = Entry(gui_form1, justify='center', font=5)
		lb3.place(x=160,y=180)
		en3.place(x=450,y=180)
# ###############################################################################
		lb4 = Label(gui_form1,text="cough:",bg='white', font=5)
		en4 = Entry(gui_form1, justify='center', font=5)
		lb4.place(x=160,y=220)
		en4.place(x=450,y=220)
# ###############################################################################
		lb5 = Label(gui_form1,text="fainting:",bg='white', font=5)
		en5 = Entry(gui_form1, justify='center', font=5)
		lb5.place(x=160,y=260)
		en5.place(x=450,y=260)
# ###############################################################################
		lb6 = Label(gui_form1,text="fatigue:",bg='white', font=5)
		en6 = Entry(gui_form1, justify='center', font=5)
		lb6.place(x=160,y=300)
		en6.place(x=450,y=300)
# ###############################################################################
		lb7 = Label(gui_form1,text="Attention Deficit:",bg='white', font=5)
		en7 = Entry(gui_form1, justify='center', font=5)
		lb7.place(x=160,y=340)
		en7.place(x=450,y=340)
# ###############################################################################
		lb8 = Label(gui_form1,text="low body temperature:",bg='white', font=5)
		en8 = Entry(gui_form1, justify='center', font=5)
		lb8.place(x=160,y=380)
		en8.place(x=450,y=380)
# ###############################################################################
		lb9 = Label(gui_form1,text="Nervous tension:",bg='white', font=5)
		en9 = Entry(gui_form1, justify='center', font=5)
		lb9.place(x=160,y=420)
		en9.place(x=450,y=420)
# ###############################################################################
		lb10 = Label(gui_form1,text="sore throat:",bg='white', font=5)
		en10 = Entry(gui_form1, justify='center', font=5)
		lb10.place(x=160,y=460)
		en10.place(x=450,y=460)
# ###############################################################################
		lb11 = Label(gui_form1,text="fever:",bg='white', font=5)
		en11= Entry(gui_form1, justify='center', font=5)
		lb11.place(x=160,y=500)
		en11.place(x=450,y=500)
# ###############################################################################
		lb12 = Label(gui_form1,text="Nausea:",bg='white', font=5)
		en12 = Entry(gui_form1, justify='center', font=5)
		lb12.place(x=160,y=540)
		en12.place(x=450,y=540)
# ###############################################################################
		lb13 = Label(gui_form1,text="blurred_vision:",bg='white', font=5)
		en13 = Entry(gui_form1, justify='center', font=5)
		lb13.place(x=160,y=580)
		en13.place(x=450,y=580)
##############################################################################
		def get_values():
			#lb2["text"] = en2.get()
			self.declare(Fact(headache=en1.get()))
			self.declare(Fact(runny_nose=en2.get()))
			self.declare(Fact(The_limbs_shiver=en3.get()))
			self.declare(Fact(cough=en4.get()))
			self.declare(Fact(fainting=en5.get()))
			self.declare(Fact(sore_throat=en6.get()))
			self.declare(Fact(fatigue=en7.get()))
			self.declare(Fact(Attention_Deficit=en8.get()))
			self.declare(Fact(low_body_temp=en9.get()))
			self.declare(Fact(fever=en10.get()))
			self.declare(Fact(Nervous_tension=en11.get()))
			self.declare(Fact(nausea=en12.get()))
			self.declare(Fact(blurred_vision=en13.get()))
#############################################################################
		btn = Button(gui_form1,command=get_values,text="get_values",bg="#123456", fg="#fff", font=5)
		btn.place(x=320,y=650)
        

            
		gui_form1.mainloop()
		yield Fact(action="find_medicine")
        

###################################################################################################
##################################################################################################

	@Rule(Fact(action='find_medicine'),Fact(headache="no"),Fact(runny_nose="no"),Fact(The_limbs_shiver="no"),Fact(cough="no"),Fact(fainting="no"),Fact(sore_throat="no"),Fact(fatigue="no"),Fact(Attention_Deficit="no"),Fact(low_body_temp="no"),Fact(fever="no"),Fact(Nervous_tension="no"),Fact(nausea="no"),Fact(blurred_vision="no"))
	def medicine_0(self):
		self.declare(Fact(medicine="You do not suffer from any disease"))

	@Rule(Fact(action='find_medicine'),Fact(headache="yes"),Fact(runny_nose="yes"),Fact(The_limbs_shiver="yes"),Fact(cough="yes"),Fact(fainting="yes"),Fact(sore_throat="yes"),Fact(fatigue="yes"),Fact(Attention_Deficit="yes"),Fact(low_body_temp="yes"),Fact(fever="yes"),Fact(Nervous_tension="yes"),Fact(nausea="yes"),Fact(blurred_vision="yes"))
	def medicine_1(self):
		self.declare(Fact(medicine="The situation is serious, please go to the hospital"))

	@Rule(Fact(action='find_medicine'),Fact(headache="yes"),Fact(runny_nose="no"),Fact(The_limbs_shiver="no"),Fact(cough="no"),Fact(fainting="no"),Fact(sore_throat="no"),Fact(fatigue="yes"),Fact(Attention_Deficit="no"),Fact(low_body_temp="no"),Fact(fever="no"),Fact(Nervous_tension="no"),Fact(nausea="no"),Fact(blurred_vision="no"))
	def medicine_2(self):
		self.declare(Fact(medicine="You should take Panadol"))

	@Rule(Fact(action='find_medicine'),Fact(headache="no"),Fact(runny_nose="yes"),Fact(The_limbs_shiver="no"),Fact(cough="yes"),Fact(fainting="no"),Fact(sore_throat="yes"),Fact(fatigue="yes"),Fact(Attention_Deficit="no"),Fact(low_body_temp="no"),Fact(fever="yes"),Fact(Nervous_tension="no"),Fact(nausea="yes"),Fact(blurred_vision="yes"))
	def medicine_3(self):
		self.declare(Fact(medicine="You should take Panadol and a fever reducer"))

	@Rule(Fact(action='find_medicine'),Fact(headache="no"),Fact(runny_nose="no"),Fact(The_limbs_shiver="no"),Fact(cough="no"),Fact(fainting="yes"),Fact(sore_throat="no"),Fact(fatigue="no"),Fact(Attention_Deficit="no"),Fact(low_body_temp="no"),Fact(fever="no"),Fact(Nervous_tension="no"),Fact(nausea="no"),Fact(blurred_vision="no"))
	def medicine_4(self):
		self.declare(Fact(medicine="You should take vitamins and tonics"))

	@Rule(Fact(action='find_medicine'),Fact(headache="no"),Fact(runny_nose="no"),Fact(The_limbs_shiver="yes"),Fact(cough="no"),Fact(fainting="no"),Fact(sore_throat="no"),Fact(fatigue="yes"),Fact(Attention_Deficit="yes"),Fact(low_body_temp="no"),Fact(fever="no"),Fact(Nervous_tension="yes"),Fact(nausea="no"),Fact(blurred_vision="no"))
	def medicine_5(self):
		self.declare(Fact(medicine="You should take milga,vitamins and tonics"))        
        
	@Rule(Fact(action='find_medicine'),Fact(headache="no"),Fact(runny_nose="no"),Fact(The_limbs_shiver="no"),Fact(cough="no"),Fact(fainting="no"),Fact(sore_throat="no"),Fact(fatigue="no"),Fact(Attention_Deficit="no"),Fact(low_body_temp="yes"),Fact(fever="no"),Fact(Nervous_tension="no"),Fact(nausea="yes"),Fact(blurred_vision="no"))
	def medicine_6(self):
		self.declare(Fact(medicine="You should take Dolasetron "))        


	@Rule(Fact(action='find_medicine'),Fact(medicine=MATCH.medicine))
	def disease(self, medicine):
		print("")
		id_medicine = medicine
		gui_form2 = Tk()
		gui_form2.title("Medical system answer")
		gui_form2.geometry("800x200")
		lb0 = Label(gui_form2,text="the result is",bg="#123456", fg="#fff",width="800", font=5)
		lb0.pack()
		var = StringVar()
		var.set(id_medicine)
		lb1 = Label(gui_form2, textvariable = var,bg="#678954", fg="#fff",width="800",height="20", font=5)
		lb1.pack()

		gui_form2.mainloop()

engine = find_medicine()
while(1):
    engine.reset()  
    engine.run()  
    print("Would you like to search for medicine again?")
    if input() == "no":
        break;
# Out:
# Would you like to search for medicine again?
